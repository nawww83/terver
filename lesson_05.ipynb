# %% [markdown]
# ## Урок 5
#
# Задачи 1,2 -искать доверительный интервал; задачи 3,4 - решать через тестирование гипотезы

# %% [markdown]
# ### 1. Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.

# %% [markdown]
# Надежности $\beta = 0.95$ соответствует параметр ${t}_{\beta} \approx 1.960$, значит доверительный интервал будет равен
#
# $ M \pm \dfrac{\sigma}{\sqrt{n}} = 80 \pm \dfrac{16}{\sqrt{256}} \cdot 1.960 = [78.04, 81.96]$

# %% [markdown]
# ### 2. В  результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные: 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1 Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95.

# %% [markdown]
# Здесь неизвестна дисперсия нормальной случайной случайной величины, поэтому воспользуемся распределением Стьюдента. Для этого найдем оценку математического ожидания
#
# $M = \dfrac{6.9 + 6.1 + 6.2 + 6.8 + 7.5 + 6.3 + 6.4 + 6.9 + 6.7 + 6.1}{10} = 6.59,$
#
# а также дисперсии
#
# $D = (\alpha^2 - M^2) \dfrac{n}{n-1} = (43.611 - 6.59^2) \dfrac{10}{9} \approx 0.20322$
#
# где
#
# $\alpha^2 = \dfrac{6.9^2 + 6.1^2 + 6.2^2 + 6.8^2 + 7.5^2 + 6.3^2 + 6.4^2 + 6.9^2 + 6.7^2 + 6.1^2}{10} = 43.611$
#
#
# По таблице для числа степеней свободы $9$ и вероятности $0.95$ определяем параметр ${t}_{\beta} = 2.26$, поэтому доверительный интервал равен
#
# $M \pm {t}_{\beta} \sqrt{\dfrac{D}{n}} = 6.59 \pm \sqrt{\dfrac{0.20322}{10}} \approx [6.447, 6.733]$

# %% [markdown]
# ### 3. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.

# %% [markdown]
# Используем z-критерий. Для параметра "альфа" $0.05$ вспомогательный параметр $z = 1.645$. Найдем нормированный параметр
#
# ${z}_{н} = \dfrac{M - {\mu}_{0}}{\frac{\sigma}{\sqrt{n}}} = \dfrac{17.5 - 17}{\frac{\sqrt{4}}{\sqrt{100}}} = 2.5 $
#
# Видим, что текущее ${z}_{н}$ больше порогового $z$, значит "все пропало", т.е. гипотеза $H_0$ неверна и средний диаметр не равен 17 мм.

# %% [markdown]
# ### 4. Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %% [markdown]
# Здесь дисперсия неизвестна, поэтому используем t-критерий (критерий Стьюдента). Для вероятности $0.99$ и числа степеней $9$ параметр  $t \approx 3.25$
#
# Оценка мат. ожидания
#
# ${\mu}_{0} = \dfrac{202 + 203 + 199 + 197 + 195 + 201 + 200 + 204 + 194 + 190}{10} = 198.5$
#
# Оценка дисперсии
#
# $D = (\alpha^2 - {{\mu}_{0}}^2) \dfrac{n}{n-1} = (39420.1 - 198.5^2) \dfrac{10}{9} \approx 19.833$
#
# где
#
# $\alpha^2 = \dfrac{202^2 + 203^2 + 199^2 + 197^2 + 195^2 + 201^2 + 200^2 + 204^2 + 194^2 + 190^2}{10} = 39420.1$
#
# Нормированный t-параметр
#
# ${t}_{н} = \dfrac{M - {\mu}_{0}}{\frac{\sigma}{\sqrt{n}}} = \dfrac{200 - 198.5}{\frac{\sqrt{19.833}}{\sqrt{10}}} \approx 1.065$
#
# Так как текущий параметр ${t}_{н}$ меньше теоретического $t$, то утверждение продавца верно.
